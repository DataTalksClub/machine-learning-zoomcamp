# %%
import os
import json

from io import BytesIO

from urllib.parse import urlparse
from urllib.parse import parse_qs

import requests
import pandas as pd

from PIL import Image
from jinja2 import Template

# %%
folder = '10-kubernetes'

# %%
with open(folder + '/meta.json') as f_in:
    data = json.load(f_in)

# %%
session = data['session']
session_name = data['name']

# %%
df = pd.read_csv(folder + '/' + data['data']).fillna('')

# %%
df.head()
# Out:
#    lesson                                            name  \
# 0       1                                        Overview
# 1       2                              TensorFlow Serving
# 2       3               Creating a pre-processing service
# 3       4  Running everything locally with Docker-compose
# 4       5                      Introduction to Kubernetes
#
#                   page_name                                        video  \
# 0            01-overview.md  https://www.youtube.com/watch?v=mvPER7YfTkw
# 1  02-tensorflow-serving.md  https://www.youtube.com/watch?v=deXR2fThYDw
# 2       03-preprocessing.md  https://www.youtube.com/watch?v=OIlrS14Zi0o
# 3      04-docker-compose.md  https://www.youtube.com/watch?v=ZhQQfpWfkKY
# 4    05-kubernetes-intro.md  https://www.youtube.com/watch?v=UjVkpszDzgk
#
#                                               slides  \
# 0  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 1
# 2
# 3  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 4  https://www.slideshare.net/AlexeyGrigorev/ml-z...
#
#                         notebook
# 0
# 1
# 2  code/tf-serving-connect.ipynb
# 3
# 4

# %%
for i in range(len(df)):
    row = df.loc[i]
    
    print('ML Zoomcamp %s.%s - %s' % (session, row.lesson, row['name'].title()))
    print()
    print()
    
    prefix = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp'
    lesson_page = '%s/%s/%s' % (prefix, folder, row.page_name)

    description = [
        'Links:',
        '',
        '- Lesson page: %s' % lesson_page,
    ]
    
    if 'notebook' in row:
        notebook_page = '%s/%s/%s' % (prefix, folder, row.notebook)
        line = '- Notebook: %s' % notebook_page
        description.append(line)
    
    if row.slides:
        line = '- Slides: %s' % row.slides
        description.append(line)
        
#     if i > 0:
#         prev_row = df.loc[i - 1]
#         line = '* Previous: [%s](%s)' % (prev_row['name'], prev_row.page_name)
#         navigation.append(line)

#     if i + 1 < len(df):
#         next_row = df.loc[i + 1]
#         line = '* Next: [%s](%s)' % (next_row['name'], next_row.page_name)
#         navigation.append(line)
    
    more_lines = [
        '- Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp',
        '- Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w',
        '- Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ',
        '- The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")',
        '',
        'Join DataTalks.Club: https://datatalks.club/slack.html'
    ]

    description.extend(more_lines)
    
    print('\n'.join(description))
    
    print()
    print()
    print()
# Out:
# ML Zoomcamp 10.1 - Overview
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/01-overview.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-10-kubernetes
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.2 - Tensorflow Serving
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/02-tensorflow-serving.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.3 - Creating A Pre-Processing Service
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/03-preprocessing.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/code/tf-serving-connect.ipynb
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.4 - Running Everything Locally With Docker-Compose
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/04-docker-compose.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-10-kubernetes
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.5 - Introduction To Kubernetes
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/05-kubernetes-intro.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-10-kubernetes
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.6 - Deploying A Simple Service To Kubernetes
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/06-kubernetes-simple-service.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-10-kubernetes
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.7 - Deploying Tensorflow Models To Kubernetes
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/07-kubernetes-tf-serving.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.8 - Deploying To Eks
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/08-eks.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.9 - Summary
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/09-summary.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.10 - Explore More
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/10-explore-more.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 10.11 - Homework
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/homework.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/10-kubernetes/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html

# %%
print('## %s. [%s](%s/)' % (session, session_name, folder))
print()

for i in range(len(df)):
    row = df.loc[i]

    print('- %s.%s [%s](%s/%s)' % (session, row.lesson, row['name'], folder, row.page_name))
# Out:
# ## 10. [Kubernetes and TensorFlow Serving](10-kubernetes/)
#
# - 10.1 [Overview](10-kubernetes/01-overview.md)
# - 10.2 [TensorFlow Serving](10-kubernetes/02-tensorflow-serving.md)
# - 10.3 [Creating a pre-processing service](10-kubernetes/03-preprocessing.md)
# - 10.4 [Running everything locally with Docker-compose](10-kubernetes/04-docker-compose.md)
# - 10.5 [Introduction to Kubernetes](10-kubernetes/05-kubernetes-intro.md)
# - 10.6 [Deploying a simple service to Kubernetes](10-kubernetes/06-kubernetes-simple-service.md)
# - 10.7 [Deploying TensorFlow models to Kubernetes](10-kubernetes/07-kubernetes-tf-serving.md)
# - 10.8 [Deploying to EKS](10-kubernetes/08-eks.md)
# - 10.9 [Summary](10-kubernetes/09-summary.md)
# - 10.10 [Explore more](10-kubernetes/10-explore-more.md)
# - 10.11 [Homework](10-kubernetes/homework.md)
