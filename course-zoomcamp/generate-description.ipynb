# %%
import os
import json

from io import BytesIO

from urllib.parse import urlparse
from urllib.parse import parse_qs

import requests
import pandas as pd

from PIL import Image
from jinja2 import Template

# %%
folder = '08-deep-learning'

# %%
with open(folder + '/meta.json') as f_in:
    data = json.load(f_in)

# %%
session = data['session']
session_name = data['name']

# %%
df = pd.read_csv(folder + '/' + data['data']).fillna('')

# %%
df.head()
# Out:
#    lesson                                       name  \
# 0       1                     Fashion classification
# 1       2                       TensorFlow and Keras
# 2       3  Pre-trained convolutional neural networks
# 3       4              Convolutional neural networks
# 4       5                          Transfer learning
#
#                       page_name                                        video  \
# 0  01-fashion-classification.md  https://www.youtube.com/watch?v=it1Lu7NmMpw
# 1        02-tensorflow-keras.md  https://www.youtube.com/watch?v=R6o_CUmoN9Q
# 2       03-pretrained-models.md  https://www.youtube.com/watch?v=qGDXEz-cr6M
# 3        04-conv-neural-nets.md  https://www.youtube.com/watch?v=BN-fnYzbdc8
# 4       05-transfer-learning.md  https://www.youtube.com/watch?v=WKHylqfNmq4
#
#                                               slides  \
# 0  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 1  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 2  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 3  https://www.slideshare.net/AlexeyGrigorev/ml-z...
# 4  https://www.slideshare.net/AlexeyGrigorev/ml-z...
#
#                                             notebook
# 0  https://github.com/alexeygrigorev/mlbookcamp-c...
# 1  https://github.com/alexeygrigorev/mlbookcamp-c...
# 2  https://github.com/alexeygrigorev/mlbookcamp-c...
# 3  https://github.com/alexeygrigorev/mlbookcamp-c...
# 4  https://github.com/alexeygrigorev/mlbookcamp-c...

# %%
for i in range(len(df)):
    row = df.loc[i]
    
    print('ML Zoomcamp %s.%s - %s' % (session, row.lesson, row['name'].title()))
    print()
    print()
    
    prefix = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp'
    lesson_page = '%s/%s/%s' % (prefix, folder, row.page_name)

    description = [
        'Links:',
        '',
        '- Lesson page: %s' % lesson_page,
    ]
    
    if 'notebook' in row:
        notebook_page = '%s/%s/%s' % (prefix, folder, row.notebook)
        line = '- Notebook: %s' % notebook_page
        description.append(line)
    
    if row.slides:
        line = '- Slides: %s' % row.slides
        description.append(line)
        
#     if i > 0:
#         prev_row = df.loc[i - 1]
#         line = '* Previous: [%s](%s)' % (prev_row['name'], prev_row.page_name)
#         navigation.append(line)

#     if i + 1 < len(df):
#         next_row = df.loc[i + 1]
#         line = '* Next: [%s](%s)' % (next_row['name'], next_row.page_name)
#         navigation.append(line)
    
    more_lines = [
        '- Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp',
        '- Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w',
        '- Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ',
        '- The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")',
        '',
        'Join DataTalks.Club: https://datatalks.club/slack.html'
    ]

    description.extend(more_lines)
    
    print('\n'.join(description))
    
    print()
    print()
    print()
# Out:
# ML Zoomcamp 8.1 - Fashion Classification
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/01-fashion-classification.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.2 - Tensorflow And Keras
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/02-tensorflow-keras.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.3 - Pre-Trained Convolutional Neural Networks
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/03-pretrained-models.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.4 - Convolutional Neural Networks
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/04-conv-neural-nets.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.5 - Transfer Learning
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/05-transfer-learning.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.6 - Adjusting The Learning Rate
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/06-learning-rate.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.7 - Checkpointing
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/07-checkpointing.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.8 - Adding More Layers
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/08-more-layers.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.9 - Regularization And Dropout
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/09-dropout.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.10 - Data Augmentation
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/10-augmentation.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.11 - Training A Larger Model
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/11-large-model.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.12 - Using The Model
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/12-using-model.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Slides: https://www.slideshare.net/AlexeyGrigorev/ml-zoomcamp-8-neural-networks-and-deep-learning-250592316
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.13 - Summary
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/13-summary.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/notebook.ipynb
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.14 - Explore More
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/14-explore-more.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html
#
#
#
# ML Zoomcamp 8.15 - Homework
#
#
# Links:
#
# - Lesson page: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/homework.md
# - Notebook: https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/08-deep-learning/
# - Course GitHub repo: https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp
# - Register here for the course: https://airtable.com/shr6Gz46UZCgJ9l6w
# - Public Google calendar: https://calendar.google.com/calendar/?cid=cGtjZ2tkbGc1OG9yb2lxa2Vwc2g4YXMzMmNAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ
# - The book - Machine Learning Bookcamp: http://bit.ly/mlbookcamp (Get 40% off with code "grigorevpc")
#
# Join DataTalks.Club: https://datatalks.club/slack.html

# %%
print('## %s. [%s](%s/)' % (session, session_name, folder))
print()

for i in range(len(df)):
    row = df.loc[i]

    print('- %s.%s [%s](%s/%s)' % (session, row.lesson, row['name'], folder, row.page_name))
# Out:
# ## 8. [Neural Networks and Deep Learning](08-deep-learning/)
#
# - 8.1 [Fashion classification](08-deep-learning/01-fashion-classification.md)
# - 8.2 [TensorFlow and Keras](08-deep-learning/02-tensorflow-keras.md)
# - 8.3 [Pre-trained convolutional neural networks](08-deep-learning/03-pretrained-models.md)
# - 8.4 [Convolutional neural networks](08-deep-learning/04-conv-neural-nets.md)
# - 8.5 [Tranfser learning](08-deep-learning/05-transer-learning.md)
# - 8.6 [Adjusting the learning rate](08-deep-learning/06-learning-rate.md)
# - 8.7 [Checkpointing](08-deep-learning/07-checkpointing.md)
# - 8.8 [Adding more layers](08-deep-learning/08-more-layers.md)
# - 8.9 [Regularization and dropout](08-deep-learning/09-dropout.md)
# - 8.10 [Data augmentation](08-deep-learning/10-augmentation.md)
# - 8.11 [Training a larger model](08-deep-learning/11-large-model.md)
# - 8.12 [Using the model](08-deep-learning/12-using-model.md)
# - 8.13 [Summary](08-deep-learning/13-summary.md)
# - 8.14 [Explore more](08-deep-learning/14-explore-more.md)
# - 8.15 [Homework](08-deep-learning/homework.md)
