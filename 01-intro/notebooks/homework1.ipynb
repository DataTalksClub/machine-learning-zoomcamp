# %%
import pandas as pd
import numpy as np

# Cargar el dataset (fíjate que usamos ../ porque estás en la carpeta notebooks)
df = pd.read_csv('car_fuel_efficiency_2026.csv')

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
len(df)
# Out:
# 10000

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
(df.isna().sum() > 0).sum()
# Out:
# np.int64(2)

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
median_before = df['horsepower'].median()
mode_hp = df['horsepower'].mode()[0]
df['horsepower'] = df['horsepower'].fillna(mode_hp)
median_after = df['horsepower'].median()
print(f"Antes: {median_before}, Después: {median_after}")
# Out:
# Antes: 254.0, Después: 252.0

# %%
X_df = df[df['origin'] == 'Asia'][['vehicle_weight', 'model_year']].head(7)
X = X_df.values
XTX = X.T @ X
XTX_inv = np.linalg.inv(XTX)
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w = XTX_inv @ X.T @ y
w.sum()
# Out:
# np.float64(0.36919696904925486)
